# %%
import pandas as pd
import numpy as np
from math import isnan

# %%
with open('PLmatches.csv') as open_file:
    df = pd.read_csv(open_file, index_col=0)

# %%
def get_prior_matches(team_name, season_num, match_timestamp, num_matches=38):
    all_prior_matches = df[((df['hometeam_name'] == team_name)|(df['awayteam_name'] == team_name))
                           #&(df['season_num'] == season_num)
                          &(df['match_timestamp'] < match_timestamp)].sort_values(by='match_timestamp')
    
    return all_prior_matches[-num_matches:]
# Out:
#               hometeam_name         awayteam_name  home_goals  away_goals  \
# 9969                Arsenal          Swansea City           0           1
# 9977      Manchester United               Arsenal           1           1
# 9980                Arsenal            Sunderland           0           0
# 9981                Arsenal  West Bromwich Albion           4           1
# 12121               Arsenal       West Ham United           0           2
# 12132        Crystal Palace               Arsenal           1           2
# 12144               Arsenal             Liverpool           0           0
# 12150      Newcastle United               Arsenal           0           1
# 12155               Arsenal            Stoke City           2           0
# 12167               Chelsea               Arsenal           2           0
# 12175        Leicester City               Arsenal           2           5
# 12192               Arsenal     Manchester United           3           0
# 12201               Watford               Arsenal           0           3
# 12205               Arsenal               Everton           2           1
# 12219          Swansea City               Arsenal           0           3
# 12232               Arsenal     Tottenham Hotspur           1           1
# 12242  West Bromwich Albion               Arsenal           2           1
# 12252          Norwich City               Arsenal           1           1
# 12255               Arsenal            Sunderland           3           1
# 12271           Aston Villa               Arsenal           0           2
# 12284               Arsenal       Manchester City           2           1
# 12291           Southampton               Arsenal           4           0
# 12295               Arsenal       AFC Bournemouth           2           0
# 12305               Arsenal      Newcastle United           1           0
# 12319             Liverpool               Arsenal           3           3
# 12333            Stoke City               Arsenal           0           0
# 12343               Arsenal               Chelsea           0           1
# 12345               Arsenal           Southampton           0           0
# 12363       AFC Bournemouth               Arsenal           0           2
# 12372               Arsenal        Leicester City           2           1
#
#             match_date  match_timestamp     match_referee  \
# 9969   Mon 11 May 2015    1431370800000      Kevin Friend
# 9977   Sun 17 May 2015    1431874800000         Mike Dean
# 9980   Wed 20 May 2015    1432147500000    Anthony Taylor
# 9981   Sun 24 May 2015    1432476000000     Robert Madley
# 12121   Sun 9 Aug 2015    1439123400000   Martin Atkinson
# 12132  Sun 16 Aug 2015    1439728200000         Lee Mason
# 12144  Mon 24 Aug 2015    1440442800000    Michael Oliver
# 12150  Sat 29 Aug 2015    1440848700000    Andre Marriner
# 12155  Sat 12 Sep 2015    1442066400000     Jonathan Moss
# 12167  Sat 19 Sep 2015    1442663100000         Mike Dean
# 12175  Sat 26 Sep 2015    1443276000000      Craig Pawson
# 12192   Sun 4 Oct 2015    1443970800000    Anthony Taylor
# 12201  Sat 17 Oct 2015    1445099400000        Mike Jones
# 12205  Sat 24 Oct 2015    1445704200000         Lee Mason
# 12219  Sat 31 Oct 2015    1446303600000      Kevin Friend
# 12345                    8.0             -28.0                  92.181818
# 12363                    4.0             292.0                 159.636364
# 12372                    1.0             -35.0                  49.500000
#
#        mean_attendance_delta
# 9969               -2.736842
# 9977              -11.842105
# 9980               -4.736842
# 9981              -20.736842
# 12121              52.105263
# 12132              96.052632
# 12144             136.105263
# 12150             634.473684
# 12155              19.105263
# 12167              83.684211
# 12175              26.315789
# 12192             140.105263
# 12201             127.263158
# 12205              41.105263
# 12219             226.052632
# 12232             116.105263
# 12242            -288.315789
# 12252             118.894737
# 12255              -6.894737
# 12271            -405.105263
# 12284             109.105263
# 12291             918.157895
# 12295              39.105263
# 12305            -686.894737
# 12319             199.263158
# 12333             148.894737
# 12343             128.105263
# 12345             100.105263
# 12363             168.263158
# 12372              65.105263
#
# [30 rows x 49 columns]

# %%
def get_mean_value_by_team(data, team_name, col_name):
    values = []
    for row_index in data.index:
        if data.loc[row_index, 'hometeam_name'] != team_name and data.loc[row_index, 'awayteam_name'] != team_name:
            continue
        team_loc = 'home' if data.loc[row_index, 'hometeam_name'] == team_name else 'away'
        values.append(data.loc[row_index, '_'.join([team_loc, col_name])])
    
    return np.mean(values)

def get_values_by_team(data, team_name, col_name):
    values = []
    for row_index in data.index:
        if data.loc[row_index, 'hometeam_name'] != team_name and data.loc[row_index, 'awayteam_name'] != team_name:
            continue
        team_loc = 'home' if data.loc[row_index, 'hometeam_name'] == team_name else 'away'
        values.append(data.loc[row_index, '_'.join([team_loc, col_name])])
    
    return values

# %%
def get_prior_home_goals(row):
    team_name = row['hometeam_name']
    season_num = row['season_num']
    cur_timestamp = row['match_timestamp']
    
    df_lastgame = get_prior_matches(team_name, season_num, cur_timestamp, 1)
    
    return get_mean_value_by_team(df_lastgame, team_name, 'goals')

def get_prior_away_goals(row):
    team_name = row['awayteam_name']
    season_num = row['season_num']
    cur_timestamp = row['match_timestamp']
    
    df_lastgame = get_prior_matches(team_name, season_num, cur_timestamp, 1)
    
    return get_mean_value_by_team(df_lastgame, team_name, 'goals')

# %%
df['home_prior_goals'] = df.apply(get_prior_home_goals, axis=1)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df['away_prior_goals'] = df.apply(get_prior_away_goals, axis=1)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
with open('PLmatches.csv', 'w') as open_file:
    df.to_csv(open_file)

# %%
df[(df['season_num'] == 4)&(df['matchweek'] == 1)]
# Out:
#                 hometeam_name    awayteam_name  home_goals  away_goals  \
# 6707              Aston Villa   Wigan Athletic           0           2
# 6708         Blackburn Rovers  Manchester City           0           2
# 6709         Bolton Wanderers       Sunderland           0           1
# 6710                  Chelsea        Hull City           2           1
# 6711                  Everton          Arsenal           1           6
# 6712               Portsmouth           Fulham           0           1
# 6713               Stoke City          Burnley           2           0
# 6714  Wolverhampton Wanderers  West Ham United           0           2
# 6715        Manchester United  Birmingham City           1           0
# 6716        Tottenham Hotspur        Liverpool           2           1
#
#            match_date  match_timestamp     match_referee  \
# 6707  Sat 15 Aug 2009    1250344800000  Mark Clattenburg
# 6708  Sat 15 Aug 2009    1250344800000         Mike Dean
# 6709  Sat 15 Aug 2009    1250344800000    Andre Marriner
# 6710  Sat 15 Aug 2009    1250336700000        Alan Wiley
# 6711  Sat 15 Aug 2009    1250353800000       Mark Halsey
# 6712  Sat 15 Aug 2009    1250344800000   Martin Atkinson
# 6713  Sat 15 Aug 2009    1250344800000     Steve Bennett
# 6714  Sat 15 Aug 2009    1250344800000         Chris Foy
# 6715  Sun 16 Aug 2009    1250425800000         Lee Mason
# 6716  Sun 16 Aug 2009    1250434800000         Phil Dowd
#
#                         match_stadium  match_attendance  home_possession  \
# 6707           Villa Park, Birmingham           35578.0             47.0
# 6708            Ewood Park, Blackburn           29584.0             43.5
# 6709           Macron Stadium, Bolton           22247.0             54.3
# 6710          Stamford Bridge, London           41597.0             67.6
# 6711         Goodison Park, Liverpool           39309.0             45.7
# 6712         Fratton Park, Portsmouth           17510.0             55.1
# 6713            bet365 Stadium, Stoke           27385.0             37.7
# 6714  Molineux Stadium, Wolverhampton           28674.0             48.6
# 6715         Old Trafford, Manchester           75062.0             63.0
# 6716          White Hart Lane, London           35935.0             47.5
#
#             ...         matchweek  stadium_capacity  season_num  \
# 6707        ...                 1             42682           4
# 6708        ...                 1             31367           4
# 6709        ...                 1             28723           4
# 6710        ...                 1             41631           4
# 6711        ...                 1             39572           4
# 6712        ...                 1             19699           4
# 6713        ...                 1             30089           4
# 6714        ...                 1             31700           4
# 6715        ...                 1             74994           4
# 6716        ...                 1             36284           4
#
#       home_prior_leaguerank  away_prior_leaguerank  attendance_delta  \
# 6707                    6.0                   11.0               NaN
# 6708                   15.0                   10.0               NaN
# 6709                   13.0                   16.0               NaN
# 6710                    3.0                   17.0               NaN
# 6711                    5.0                    4.0               NaN
# 6712                   14.0                    7.0               NaN
# 6713                   12.0                    NaN               NaN
# 6714                    NaN                    9.0               NaN
# 6715                    1.0                   19.0               NaN
# 6716                    8.0                    2.0               NaN
#
#       mean_attendance_delta_std  mean_attendance_delta  home_prior_goals  \
# 6707                        NaN           -2995.421053               1.0
# 6708                        NaN            4155.842105               0.0
# 6709                        NaN             366.105263               0.0
# 6710                        NaN             174.421053               3.0
# 6711                        NaN                    NaN               2.0
# 6712                        NaN            -739.315789               0.0
# 6713                        NaN                    NaN               1.0
# 6714                        NaN             308.263158               NaN
# 6715                        NaN             197.578947               1.0
# 6716                        NaN             140.736842               1.0
#
#       away_prior_goals
# 6707               1.0
# 6708               1.0
# 6709               2.0
# 6710               0.0
# 6711               4.0
# 6712               0.0
# 6713               NaN
# 6714               2.0
# 6715               4.0
# 6716               3.0
#
# [10 rows x 51 columns]
