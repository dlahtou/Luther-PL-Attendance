# %%
import pandas as pd
import numpy as np
from math import isnan

# %%
with open('PLmatches.csv') as open_file:
    df = pd.read_csv(open_file, index_col=0)

# %%
def get_prior_matches(team_name, season_num, match_timestamp, num_matches=38):
    all_prior_matches = df[((df['hometeam_name'] == team_name)|(df['awayteam_name'] == team_name))
                           #&(df['season_num'] == season_num)
                          &(df['match_timestamp'] < match_timestamp)].sort_values(by='match_timestamp')
    
    return all_prior_matches[-num_matches:]

# %%
def get_mean_value_by_team(data, team_name, col_name):
    values = []
    for row_index in list(data.index.values):
        if data.loc[row_index, 'hometeam_name'] != team_name and data.loc[row_index, 'awayteam_name'] != team_name:
            continue
        team_loc = 'home' if data.loc[row_index, 'hometeam_name'] == team_name else 'away'
        values.append(data.loc[row_index, '_'.join([team_loc, col_name])])
    
    return np.mean(values)

def get_values_by_team(data, team_name, col_name):
    values = []
    for row_index in data.index.values:
        if data.loc[row_index, 'hometeam_name'] != team_name and data.loc[row_index, 'awayteam_name'] != team_name:
            continue
        team_loc = 'home' if data.loc[row_index, 'hometeam_name'] == team_name else 'away'
        values.append(data.loc[row_index, '_'.join([team_loc, col_name])])
    
    return values

# %%
def get_last3_home_goals(row):
    team_name = row['hometeam_name']
    season_num = row['season_num']
    cur_timestamp = row['match_timestamp']
    
    df_lastgame = get_prior_matches(team_name, season_num, cur_timestamp, 3)
    
    return get_mean_value_by_team(df_lastgame, team_name, 'goals')

def get_last3_away_goals(row):
    team_name = row['awayteam_name']
    season_num = row['season_num']
    cur_timestamp = row['match_timestamp']
    
    df_lastgame = get_prior_matches(team_name, season_num, cur_timestamp, 3)
    
    return get_mean_value_by_team(df_lastgame, team_name, 'goals')

# %%
df['home_last3_goals'] = df.apply(get_prior_home_goals, axis=1)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df['away_last3_goals'] = df.apply(get_prior_away_goals, axis=1)
# Out:
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/dlahtou/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
with open('PLmatches.csv', 'w') as open_file:
    df.to_csv(open_file)

# %%
df[((df['hometeam_name'] == 'Aston Villa')|(df['awayteam_name'] == 'Aston Villa'))&(df['season_num'] == 4)]
# Out:
#                 hometeam_name            awayteam_name  home_goals  \
# 6707              Aston Villa           Wigan Athletic           0
# 6732                Liverpool              Aston Villa           1
# 6740              Aston Villa                   Fulham           2
# 6751          Birmingham City              Aston Villa           0
# 6754              Aston Villa               Portsmouth           2
# 6764         Blackburn Rovers              Aston Villa           2
# 6782              Aston Villa          Manchester City           1
# 6784              Aston Villa                  Chelsea           2
# 6798  Wolverhampton Wanderers              Aston Villa           1
# 6806                  Everton              Aston Villa           1
# 6813          West Ham United              Aston Villa           2
# 6814              Aston Villa         Bolton Wanderers           5
# 6825                  Burnley              Aston Villa           1
# 6836              Aston Villa        Tottenham Hotspur           1
# 6847              Aston Villa                Hull City           3
# 6861        Manchester United              Aston Villa           0
# 6869               Sunderland              Aston Villa           0
# 6875              Aston Villa               Stoke City           1
# 6891                  Arsenal              Aston Villa           3
# 6899              Aston Villa                Liverpool           0
# 6913              Aston Villa          West Ham United           0
# 6923              Aston Villa                  Arsenal           0
# 6929                   Fulham              Aston Villa           0
# 6946        Tottenham Hotspur              Aston Villa           0
# 6954              Aston Villa        Manchester United           1
# 6966              Aston Villa                  Burnley           5
# 6993               Stoke City              Aston Villa           0
# 6998           Wigan Athletic              Aston Villa           1
# 7000              Aston Villa  Wolverhampton Wanderers           2
# 7010              Aston Villa               Sunderland           1
# 7016                  Chelsea              Aston Villa           7
# 7025         Bolton Wanderers              Aston Villa           0
# 7041              Aston Villa                  Everton           2
# 7051               Portsmouth              Aston Villa           1
# 7054                Hull City              Aston Villa           0
# 7061              Aston Villa          Birmingham City           1
# 7066          Manchester City              Aston Villa           3
# 7078              Aston Villa         Blackburn Rovers           0
#
#       away_goals       match_date  match_timestamp     match_referee  \
# 6707           2  Sat 15 Aug 2009    1250344800000  Mark Clattenburg
# 6732           3  Mon 24 Aug 2009    1251140400000   Martin Atkinson
# 6740           0  Sun 30 Aug 2009    1251644400000     Steve Bennett
# 6751           1  Sun 13 Sep 2009    1252839600000       Howard Webb
# 6754           0  Sat 19 Sep 2009    1253368800000    Stuart Attwell
# 6764           1  Sat 26 Sep 2009    1253973600000  Mark Clattenburg
# 6782           1   Mon 5 Oct 2009    1254769200000         Mike Dean
# 6784           1  Sat 17 Oct 2009    1255779900000      Kevin Friend
# 6798           1  Sat 24 Oct 2009    1256384700000      Peter Walton
# 6806           1  Sat 31 Oct 2009    1257001200000       Lee Probert
# 6813           1   Wed 4 Nov 2009    1257363900000     Steve Bennett
# 6814           1   Sat 7 Nov 2009    1257606000000  Mark Clattenburg
# 6825           1  Sat 21 Nov 2009    1258815600000       Howard Webb
# 6836           1  Sat 28 Nov 2009    1259429400000         Phil Dowd
# 6847           0   Sat 5 Dec 2009    1260025200000    Stuart Attwell
# 6861           1  Sat 12 Dec 2009    1260639000000   Martin Atkinson
# 6869           2  Tue 15 Dec 2009    1260906300000      Kevin Friend
# 6875           0  Sat 19 Dec 2009    1261234800000       Lee Probert
# 6891           0  Sun 27 Dec 2009    1261920600000         Phil Dowd
# 6899           1  Tue 29 Dec 2009    1262115900000       Lee Probert
# 6913           0  Sun 17 Jan 2010    1263735000000        Mike Jones
# 6923           0  Wed 27 Jan 2010    1264621500000       Lee Probert
# 6929           2  Sat 30 Jan 2010    1264863600000         Lee Mason
# 6946           0   Sat 6 Feb 2010    1265477400000         Chris Foy
# 6954           1  Wed 10 Feb 2010    1265831100000      Peter Walton
# 6966           2  Sun 21 Feb 2010    1266760800000    Stuart Attwell
# 6993           0  Sat 13 Mar 2010    1268492400000      Kevin Friend
# 6998           2  Tue 16 Mar 2010    1268768700000     Steve Bennett
# 7000           2  Sat 20 Mar 2010    1269089100000  Mark Clattenburg
# 7010           1  Wed 24 Mar 2010    1269459900000         Mike Dean
# 7016           1  Sat 27 Mar 2010    1269702000000      Peter Walton
# 7025           1   Sat 3 Apr 2010    1270303200000        Mike Jones
# 7041           2  Wed 14 Apr 2010    1271270700000   Martin Atkinson
# 7051           2  Sun 18 Apr 2010    1271602800000       Lee Probert
# 7054           2  Wed 21 Apr 2010    1271875500000         Mike Dean
# 7061           0  Sun 25 Apr 2010    1272193200000   Martin Atkinson
# 7066           1   Sat 1 May 2010    1272722400000  Mark Clattenburg
# 7078           1   Sun 9 May 2010    1273417200000     Steve Bennett
#
#                         match_stadium  match_attendance  home_possession  \
# 6707           Villa Park, Birmingham           35578.0             47.0
# 6732               Anfield, Liverpool           43667.0             67.4
# 6740           Villa Park, Birmingham           32917.0             44.1
# 6751           St Andrews, Birmingham           25196.0             50.3
# 6754           Villa Park, Birmingham           35979.0             49.0
# 6764            Ewood Park, Blackburn           25172.0             47.5
# 6782           Villa Park, Birmingham           37924.0             43.8
# 6784           Villa Park, Birmingham           39047.0             34.5
# 6798  Molineux Stadium, Wolverhampton           28734.0             48.4
# 6806         Goodison Park, Liverpool           36648.0             47.7
# 6813            Boleyn Ground, London           30024.0             54.2
# 6814           Villa Park, Birmingham           38101.0             56.6
# 6825               Turf Moor, Burnley           21178.0             47.4
# 6836           Villa Park, Birmingham           39866.0             36.6
# 6847           Villa Park, Birmingham           39748.0             47.3
# 6861         Old Trafford, Manchester           75130.0             67.2
# 6869     Stadium of Light, Sunderland           34821.0             57.6
# 6875           Villa Park, Birmingham           35852.0             53.0
# 6891         Emirates Stadium, London           60056.0             61.5
# 6899           Villa Park, Birmingham           42788.0             43.4
# 6913           Villa Park, Birmingham           35646.0             57.3
# 6923           Villa Park, Birmingham           39601.0             48.7
# 6929           Craven Cottage, London           25408.0             54.1
# 6946          White Hart Lane, London           35899.0             56.2
# 6954           Villa Park, Birmingham           42788.0             47.8
# 6966           Villa Park, Birmingham           38709.0             47.9
# 6993            bet365 Stadium, Stoke           27598.0             41.3
# 6998                DW Stadium, Wigan           16186.0             54.0
# 7000           Villa Park, Birmingham           37562.0             53.3
# 7010           Villa Park, Birmingham           37473.0             48.0
# 7016          Stamford Bridge, London           41825.0             60.4
# 7025           Macron Stadium, Bolton           21111.0             52.4
# 7041           Villa Park, Birmingham           38729.0             55.1
# 7051         Fratton Park, Portsmouth           16523.0             42.7
# 7054               KCOM Stadium, Hull           23842.0             49.9
# 7061           Villa Park, Birmingham           42788.0             50.8
# 7066       Etihad Stadium, Manchester           47102.0             53.9
# 7078           Villa Park, Birmingham           41799.0             65.1
#
#             ...         home_prior_leaguerank  away_prior_leaguerank  \
# 6707        ...                           6.0                   11.0
# 6732        ...                           4.0                   16.0
# 6740        ...                          12.0                   13.0
# 6751        ...                          12.0                    8.0
# 6754        ...                           6.0                   20.0
# 6764        ...                          18.0                    5.0
# 6782        ...                           7.0                    5.0
# 6784        ...                           7.0                    1.0
# 6798        ...                          16.0                    6.0
# 6806        ...                          14.0                    7.0
# 6813        ...                          16.0                    7.0
# 6814        ...                           7.0                   15.0
# 6825        ...                          10.0                    5.0
# 6836        ...                           5.0                    4.0
# 6847        ...                           6.0                   15.0
# 6861        ...                           2.0                    5.0
# 6869        ...                          10.0                    4.0
# 6875        ...                           4.0                   11.0
# 6891        ...                           3.0                    4.0
# 6899        ...                           6.0                    7.0
# 6913        ...                           6.0                   17.0
# 6923        ...                           7.0                    2.0
# 6929        ...                          10.0                    7.0
# 6946        ...                           4.0                    7.0
# 6954        ...                           7.0                    2.0
# 6966        ...                           7.0                   19.0
# 6993        ...                          11.0                    7.0
# 6998        ...                          15.0                    7.0
# 7000        ...                           7.0                   17.0
# 7010        ...                           7.0                   13.0
# 7016        ...                           2.0                    7.0
# 7025        ...                          15.0                    7.0
# 7041        ...                           7.0                    8.0
# 7051        ...                          20.0                    7.0
# 7054        ...                          18.0                    6.0
# 7061        ...                           6.0                    9.0
# 7066        ...                           6.0                    5.0
# 7078        ...                           6.0                   11.0
#
#       attendance_delta  mean_attendance_delta_std  mean_attendance_delta  \
# 6707               NaN                        NaN           -2995.421053
# 6732            -651.0                -651.000000             803.263158
# 6740           -2661.0               -2661.000000           -5656.421053
# 6751            3502.0                4388.000000             -50.315789
# 6754            3062.0                1731.500000           -2594.421053
# 6764             327.0                -778.000000            -256.157895
# 6782            1945.0                3099.333333            -649.421053
# 6784            1123.0                3447.500000             473.578947
# 6798            -289.0                 415.750000             368.263158
# 6806               NaN                        NaN                    NaN
# 6813           -4418.0               -3677.750000           -3659.315789
# 6814            -946.0                1812.000000            -472.421053
# 6825             959.0                1044.333333                    NaN
# 6836            1765.0                3275.000000            1292.578947
# 6847            -118.0                2689.142857            1174.578947
# 6861             -39.0                  91.857143             265.578947
# 6869           -2757.0                        NaN                    NaN
# 6875           -3896.0               -1543.000000           -2721.421053
# 6891              50.0                        NaN                    NaN
# 6899            6936.0                5564.444444            4214.578947
# 6913           -7142.0               -2134.000000           -2927.421053
# 6923            3955.0                2015.000000            1027.578947
# 6929            -271.0                1062.700000            1498.736842
# 6946             432.0                 129.916667             104.736842
# 6954            3187.0                5034.083333            4214.578947
# 6966           -4079.0                 567.846154             135.578947
# 6993             587.0                        NaN                    NaN
# 6998           -1241.0               -1725.142857           -1820.210526
# 7000           -1147.0                -619.714286           -1011.421053
# 7010             -89.0                -667.400000           -1100.421053
# 7016              70.0                 340.400000             402.421053
# 7025           -4259.0                -841.312500            -769.894737
# 7041            1256.0                 630.312500             155.578947
# 7051             316.0               -1771.176471           -1726.315789
# 7054            -527.0                        NaN                    NaN
# 7061            4059.0                4652.235294            4214.578947
# 7066              83.0                1792.117647            1589.368421
# 7078            -989.0                3404.777778            3225.578947
#
#       home_prior_goals  away_prior_goals  mean_attendance_delta_normalized  \
# 6707               1.0               1.0                         -1.125334
# 6732               4.0               0.0                          0.479355
# 6740               3.0               0.0                         -2.125031
# 6751               1.0               2.0                         -0.018475
# 6754               1.0               2.0                         -0.974685
# 6764               0.0               2.0                         -0.107877
# 6782               1.0               3.0                         -0.243978
# 6784               1.0               2.0                          0.177916
# 6798               1.0               2.0                          0.521100
# 6806               2.0               1.0                          0.031494
# 6813               2.0               1.0                         -3.204069
# 6814               1.0               0.0                         -0.177481
# 6825               3.0               5.0                          0.582232
# 6836               1.0               9.0                          0.485602
# 6847               1.0               1.0                          0.441271
# 6861               4.0               3.0                          0.532701
# 6869               1.0               1.0                         -1.429322
# 6875               2.0               2.0                         -1.022397
# 6891               3.0               1.0                          0.422260
# 6899               0.0               2.0                          1.583353
# 6913               0.0               0.0                         -1.099788
# 6923               0.0               4.0                          0.386046
# 6929               0.0               0.0                          0.920240
# 6946               1.0               2.0                          0.490710
# 6954               0.0               5.0                          1.583353
# 6966               1.0               0.0                          0.050935
# 6993               1.0               5.0                          1.135133
# 6998               0.0               0.0                         -0.950219
# 7000               2.0               2.0                         -0.379976
# 7010               2.0               3.0                         -0.413411
# 7016               5.0               1.0                          0.821527
# 7025               0.0               1.0                         -0.464776
# 7041               1.0               2.0                          0.058449
# 7051               0.0               2.0                         -1.199233
# 7054               0.0               2.0                         -0.775160
# 7061               2.0               0.0                          1.583353
# 7066               0.0               1.0                          0.763840
# 7078               1.0               2.0                          1.211801
#
#       home_last3_goals  away_last3_goals
# 6707          1.000000          0.666667
# 6732          2.666667          0.666667
# 6740          1.333333          0.333333
# 6751          0.666667          1.666667
# 6754          2.000000          1.000000
# 6764          1.000000          1.666667
# 6782          1.333333          3.333333
# 6784          1.333333          2.000000
# 6798          1.000000          1.333333
# 6806          1.333333          1.333333
# 6813          1.666667          1.333333
# 6814          1.000000          1.333333
# 6825          2.000000          2.333333
# 6836          2.333333          3.666667
# 6847          2.333333          2.333333
# 6861          3.666667          1.666667
# 6869          0.333333          1.666667
# 6875          2.000000          0.666667
# 6891          2.000000          1.333333
# 6899          1.000000          1.333333
# 6913          0.333333          1.000000
# 6923          0.000000          2.666667
# 6929          0.666667          0.000000
# 6946          1.000000          0.666667
# 6954          0.666667          4.000000
# 6966          1.000000          1.000000
# 6993          1.333333          2.000000
# 6998          0.333333          2.000000
# 7000          2.333333          0.666667
# 7010          1.333333          2.666667
# 7016          3.333333          1.666667
# 7025          1.333333          1.333333
# 7041          1.000000          1.333333
# 7051          0.000000          1.333333
# 7054          0.333333          1.666667
# 7061          2.000000          0.666667
# 7066          1.666667          1.666667
# 7078          1.333333          1.666667
#
# [38 rows x 54 columns]
